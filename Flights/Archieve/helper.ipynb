# %%
import numpy as np
from bs4 import BeautifulSoup as BS
import requests
# Out:
# /usr/local/lib/python2.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.23) or chardet (2.0.3) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
url = "https://www.expedia.com/Flights-Search?flight-type=on&starDate=07%2F01%2F2020&mode=search&trip=oneway&leg1=from%3ADelhi+%28DEL-Indira+Gandhi+Intl.%29%2Cto%3AMumbai+%28BOM-Chhatrapati+Shivaji+Intl.%29%2Cdeparture%3A07%2F01%2F2020TANYT&passengers=children%3A0%2Cadults%3A1%2Cseniors%3A0%2Cinfantinlap%3AY&fareCalendarPrice=99"
r = requests.get(url)

# %%
soup = BS(r.text,'html.parser')
print type(soup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
startingPoint = []
destination = []
date_of_travel = []
airlines = []
duration = []
prices = []
coupons= []

# %%
entriesList = soup.find_all('li')

# %%
print len(entriesList)
# Out:
# 141

# %%
for ix in entriesList:
    print ix
# Out:
# <li>
# <a data-onclick="xp.nav.trackAnalytics(this,'a','Footer.CorporateLink')" data-qualifier_app_url="https://www.expediagroup.com/" href="https://www.expediagroup.com/">
#
#                                               About Expedia
#
#                                         </a>
# </li>
# <li>
# <a data-onclick="xp.nav.trackAnalytics(this,'a','Footer.CorporateLink')" data-qualifier_app_url="https://lifeatexpediagroup.com/" href="https://lifeatexpediagroup.com/">
#
#                                               Jobs
#
#                                         </a>
# </li>
# <li>
# <a data-onclick="xp.nav.trackAnalytics(this,'a','Footer.CorporateLink')" data-qualifier_app_url="http://ir.expediagroup.com/" href="http://ir.expediagroup.com/">
#
#                                               Investor Relations
#
#                                         </a>
# </li>
# <li>
# ...

# %%
temp = soup.find_all("li",{"class":"flight-module segment offer-listing open"})

# %%
print temp
# Out:
# []

# %%
# print temp
